# %% [markdown]
# # Escher map

# %%
import escher
from escher import Builder
import cobra
from time import sleep

builder = Builder(

     model_name='iMM904',
     map_name='iMM904.Central carbon metabolism'
)
builder
# Out:
# ...
# Builder()
